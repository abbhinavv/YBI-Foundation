# %%
import pandas as pd

# %%
import numpy as np

# %%
df =pd.read_csv('https://raw.githubusercontent.com/YBI-Foundation/Dataset/6984a5ac53dd5cd0a04e9ae59e8de07a74d5dc95/Big%20Sales%20Data.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDT36         12.3          Low Fat         0.111448
# 1           FDT36         12.3          Low Fat         0.111904
# 2           FDT36         12.3               LF         0.111728
# 3           FDT36         12.3          Low Fat         0.000000
# 4           FDP12          9.8          Regular         0.045523
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   33.4874            OUT049                       1999
# 1  Baking Goods   33.9874            OUT017                       2007
# 2  Baking Goods   33.9874            OUT018                       2009
# 3  Baking Goods   34.3874            OUT019                       1985
# 4  Baking Goods   35.0874            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1         436.608721
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11815 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df.isnull()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                False        False             False            False
# 1                False        False             False            False
# 2                False        False             False            False
# 3                False        False             False            False
# 4                False        False             False            False
# ...                ...          ...               ...              ...
# 14199            False        False             False            False
# 14200            False        False             False            False
# 14201            False        False             False            False
# 14202            False         True             False            False
# 14203            False        False             False            False
#
#        Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df['Item_Weight'].fillna(df.groupby(['Item_Type'])['Item_Weight'].transform('mean'),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  int64
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 1.3+ MB

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.shape
# Out:
# (14204, 12)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df[['Item_Identifier']].value_counts()
# Out:
# Item_Identifier
# FDQ08              10
# FDO24              10
# FDQ19              10
# FDQ28              10
# FDQ31              10
#                    ..
# FDM52               7
# FDM50               7
# FDL50               7
# FDM10               7
# FDR51               7
# Length: 1559, dtype: int64

# %%
df[['Item_Weight']].value_counts()
# Out:
# Item_Weight
# 12.724441      1229
# 12.867687       335
# 13.332012       261
# 13.169810       147
# 17.600000       135
#                ...
# 7.145000          7
# 7.850000          6
# 9.035000          6
# 4.615000          6
# 30.000000         1
# Length: 425, dtype: int64

# %%
df.replace({'Item_Fat_Content':{'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'}},inplace = True)

# %%
df[['Item_Fat_Content']].value_counts()
# Out:
# Item_Fat_Content
# 0                   8485
# 1                   4824
# Low Fat              700
# Regular              195
# dtype: int64

# %%
df.replace({'Item_Fat_Content' : {'Low Fat':0,'Regular':1}},inplace=True)

# %%
df.describe()
# Out:
#         Item_Weight  Item_Fat_Content  Item_Visibility      Item_MRP  \
# count  14204.000000      14204.000000     14204.000000  14204.000000
# mean      12.788499          0.353351         0.065953    141.004977
# std        4.248896          0.478027         0.051459     62.086938
# min        4.555000          0.000000         0.000000     31.290000
# 25%        9.300000          0.000000         0.027036     94.012000
# 50%       12.724441          0.000000         0.054021    142.247000
# 75%       16.000000          1.000000         0.094037    185.855600
# max       30.000000          1.000000         0.328391    266.888400
#
#        Outlet_Establishment_Year   Outlet_Type  Item_Outlet_Sales
# count               14204.000000  14204.000000       14204.000000
# mean                 1997.830681      1.201281        2185.836320
# std                     8.371664      0.796543        1827.479550
# min                  1985.000000      0.000000          33.290000
# ...

# %%
df[['Item_Type']].value_counts()
# Out:
# Item_Type
# 0                     7382
# Snack Foods           1989
# Household             1548
# Health and Hygiene     858
# Meat                   736
# Soft Drinks            726
# Breads                 416
# Others                 280
# Starchy Foods          269
# dtype: int64

# %%
df.replace({'Item_Type':{'Fruits and Vegetables':0,'Snack Foods ':0,'Household ':1,'Frozen Foods':0,'Dairy':0,'Baking Goods':0,'Canned':0,'Health and Hygiene ':1,'Meat ':0,'Soft Drinks ':0,'Breads ':0,'Hard Drinks':0,'Others  ':2,'Starchy Foods  ':0,'Starchy Foods ':0,'Breakfast':0,'Seafood':0}},inplace=True)

# %%
df[['Item_Type']].value_counts()
# Out:
# Item_Type
# 0                     7382
# Snack Foods           1989
# Household             1548
# Health and Hygiene     858
# Meat                   736
# Soft Drinks            726
# Breads                 416
# Others                 280
# Starchy Foods          269
# dtype: int64

# %%
df[['Outlet_Identifier']].value_counts()
# Out:
# Outlet_Identifier
# 0                    1559
# 1                    1553
# 2                    1550
# OUT035               1550
# OUT046               1550
# OUT045               1548
# 6                    1546
# 7                    1543
# 8                     925
# OUT019                880
# dtype: int64

# %%
df[['Outlet_Identifier']].value_counts()
# Out:
# Outlet_Identifier
# 0                    1559
# 1                    1553
# 2                    1550
# OUT035               1550
# OUT046               1550
# OUT045               1548
# 6                    1546
# 7                    1543
# 8                     925
# OUT019                880
# dtype: int64

# %%
df[['Outlet_Identifier']].value_counts()
# Out:
# Outlet_Identifier
# 0                    1559
# 1                    1553
# 2                    1550
# OUT035               1550
# OUT046               1550
# OUT045               1548
# 6                    1546
# 7                    1543
# 8                     925
# OUT019                880
# dtype: int64

# %%
df.replace({'Outlet_Identifier':{'OUT027':0,'OUT013':1,
                                 'OUT049':2,'OUT018':6,
                                 'OUT017':7,'OUT010':8,'Out019':9}},inplace= True)

# %%
df[['Outlet_Size']].value_counts()
# Out:
# Outlet_Size
# Medium         7122
# Small          5529
# High           1553
# dtype: int64

# %%
df.replace({'Outlet_Location_type':{'Tier 1':0,'Tier 2':1,'Tier 3' : 2}},inplace=True)

# %%
df[['Outlet_Location_Type']].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3                  5583
# Tier 2                  4641
# Tier 1                  3980
# dtype: int64

# %%
df[['Outlet_Type']].value_counts()
# Out:
# Outlet_Type
# 1              9294
# 0              1805
# 3              1559
# 2              1546
# dtype: int64

# %%
df.replace({'Outlet_Type':{'Grocery Store':0,'Supermarket Type1':1,'Supermarket Type2':2,'Supermarket Type3':3}},inplace =  True)

# %%
df[['Outlet_Type']].value_counts()
# Out:
# Outlet_Type
# 1              9294
# 0              1805
# 3              1559
# 2              1546
# dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDT36         12.3                 0         0.111448         0
# 1           FDT36         12.3                 0         0.111904         0
# 2           FDT36         12.3                 0         0.111728         0
# 3           FDT36         12.3                 0         0.000000         0
# 4           FDP12          9.8                 1         0.045523         0
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0   33.4874                 2                       1999      Medium
# 1   33.9874                 7                       2007      Medium
# 2   33.9874                 6                       2009      Medium
# 3   34.3874            OUT019                       1985       Small
# 4   35.0874                 7                       2007      Medium
#
#   Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  int64
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  int64
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (14204, 12)

# %%
y= df['Item_Outlet_Sales']

# %%
y.shape
# Out:
# (14204,)

# %%
y
# Out:
# 0         436.608721
# 1         443.127721
# 2         564.598400
# 3        1719.370000
# 4         352.874000
#             ...
# 14199    4984.178800
# 14200    2885.577200
# 14201    2885.577200
# 14202    3803.676434
# 14203    3644.354765
# Name: Item_Outlet_Sales, Length: 14204, dtype: float64

# %%
x=df[[ 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
       'Item_Type', 'Item_MRP', 'Outlet_Identifier',
       'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
       'Outlet_Type', 'Item_Outlet_Sales']]

# %%
X =df.drop(['Item_Identifier','Item_Outlet_Sales'],axis=1)

# %%
X.shape
# Out:
# (14204, 10)

# %%
X
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility      Item_Type  \
# 0        12.300000                 0         0.111448              0
# 1        12.300000                 0         0.111904              0
# 2        12.300000                 0         0.111728              0
# 3        12.300000                 0         0.000000              0
# 4         9.800000                 1         0.045523              0
# ...            ...               ...              ...            ...
# 14199    12.800000                 0         0.069606  Starchy Foods
# 14200    12.800000                 0         0.070013  Starchy Foods
# 14201    12.800000                 0         0.069561  Starchy Foods
# 14202    13.659758                 0         0.069282  Starchy Foods
# 14203    12.800000                 0         0.069727  Starchy Foods
#
#        Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
from sklearn.preprocessing  import StandardScaler

# %%
sc = StandardScaler()

# %%
X_std= df[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']]

# %%
X_std =sc.fit_transform(X_std)

# %%
x_std
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year
# 0        12.300000         0.111448   33.4874                       1999
# 1        12.300000         0.111904   33.9874                       2007
# 2        12.300000         0.111728   33.9874                       2009
# 3        12.300000         0.000000   34.3874                       1985
# 4         9.800000         0.045523   35.0874                       2007
# ...            ...              ...       ...                        ...
# 14199    12.800000         0.069606  261.9252                       2004
# 14200    12.800000         0.070013  262.8252                       2007
# 14201    12.800000         0.069561  263.0252                       1987
# 14202    13.659758         0.069282  263.5252                       1985
# 14203    12.800000         0.069727  263.6252                       1999
#
# [14204 rows x 4 columns]

# %%
X[['Item_Weight','Item_Visibilty','Item_MRP','Outlet_Establishment_year']] =pd.DataFrame(X_std,columns =[['Item_Weight',"Item_Visibilty",'Item_MRP','Outlet_Establishment_Year']])

# %%
X
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility      Item_Type  \
# 0        -0.114975                 0         0.111448              0
# 1        -0.114975                 0         0.111904              0
# 2        -0.114975                 0         0.111728              0
# 3        -0.114975                 0         0.000000              0
# 4        -0.703384                 1         0.045523              0
# ...            ...               ...              ...            ...
# 14199     0.002707                 0         0.069606  Starchy Foods
# 14200     0.002707                 0         0.070013  Starchy Foods
# 14201     0.002707                 0         0.069561  Starchy Foods
# 14202     0.205062                 0         0.069282  Starchy Foods
# 14203     0.002707                 0         0.069727  Starchy Foods
#
#        Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.1,random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((12783, 12), (1421, 12), (12783,), (1421,))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr =RandomForestRegressor(random_state=2529)

# %%
rfr=[float(X) for X in rfr if X != '.']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-ccad265b56d9> in <module>()
# ----> 1 rfr=[float(X) for X in rfr if X != '.']
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_base.py in __iter__(self)
#     186     def __iter__(self):
#     187         """Return iterator over estimators in the ensemble."""
# --> 188         return iter(self.estimators_)
#     189
#     190
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'estimators_'

# %%
rfr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-1cbcea6d6ce5> in <module>()
# ----> 1 rfr.fit(X_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     326             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     327         X, y = self._validate_data(
# --> 328             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     329         )
#     330         if sample_weight is not None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
y_pred =rfr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-9d4b9d131a88> in <module>()
# ----> 1 y_pred =rfr.predict(X_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     969         check_is_fitted(self)
#     970         # Check data
# --> 971         X = self._validate_X_predict(X)
#     972
#     973         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     577         Validate X whenever one tries to predict, apply, predict_proba."""
#     578         check_is_fitted(self)
# --> 579         X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     580         if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
# ...

# %%
y_pred.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-a950412d13d5> in <module>()
# ----> 1 y_pred.shape
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)

# %%
mean_absolute_error(y_test,y_pred)

# %%
r2_score(y_test,y_pred)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_test)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()
